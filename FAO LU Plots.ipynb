# %% [markdown]
# ## Author: Riyaz Khan

# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %%
df1=pd.read_excel('/Users/riyazkhan/Downloads/plot data/africa.xls')

# %%
df1.head()
# Out:
#   Domain Code          Domain  Area Code (FAO)    Area  Element Code  \
# 0          GL  Land Use Total             5100  Africa          7217
# 1          GL  Land Use Total             5100  Africa          7217
# 2          GL  Land Use Total             5100  Africa          7217
# 3          GL  Land Use Total             5100  Africa          7217
# 4          GL  Land Use Total             5100  Africa          7217
#
#                           Element  Item Code         Item  Year Code  Year  \
# 0  Net emissions/removals (CO2eq)       5065  Forest land       1990  1990
# 1  Net emissions/removals (CO2eq)       5065  Forest land       1991  1991
# 2  Net emissions/removals (CO2eq)       5065  Forest land       1992  1992
# 3  Net emissions/removals (CO2eq)       5065  Forest land       1993  1993
# 4  Net emissions/removals (CO2eq)       5065  Forest land       1994  1994
#
#         Unit        Value Flag  \
# 0  gigagrams  900964.7837    A
# 1  gigagrams  900964.7837    A
# ...

# %%
sns.lineplot(x='Year',y='Value',hue="Item",data=df1).set_title('Net emissions from Africa')
# Out:
# Text(0.5, 1.0, 'Net emissions from Africa')

# %%
df2=pd.read_excel('/Users/riyazkhan/Downloads/plot data/north_america.xls')
sns.lineplot(x='Year',y='Value',hue="Item",data=df2).set_title('Net emissions from North America')
# Out:
# Text(0.5, 1.0, 'Net emissions from North America')

# %%
df3=pd.read_excel('/Users/riyazkhan/Downloads/plot data/south_america.xls')
sns.lineplot(x='Year',y='Value',hue="Item",data=df3).set_title('Net emissions from South America')
# Out:
# Text(0.5, 1.0, 'Net emissions from South America')

# %%
df4=pd.read_excel('/Users/riyazkhan/Downloads/plot data/asia.xls')
sns.lineplot(x='Year',y='Value',hue="Item",data=df4).set_title('Net emissions from Asia')
# Out:
# Text(0.5, 1.0, 'Net emissions from Asia')

# %%
df5=pd.read_excel('/Users/riyazkhan/Downloads/plot data/europe.xls')
sns.lineplot(x='Year',y='Value',hue="Item",data=df5).set_title('Net emissions from Europe')
# Out:
# Text(0.5, 1.0, 'Net emissions from Europe')

# %%
df6=pd.read_excel('/Users/riyazkhan/Downloads/plot data/oceania.xls')
sns.lineplot(x='Year',y='Value',hue="Item",data=df6).set_title('Net emissions from Oceania')
# Out:
# Text(0.5, 1.0, 'Net emissions from Oceania')

# %%
df7=pd.read_excel('/Users/riyazkhan/Downloads/plot data/world.xls')
sns.lineplot(x='Year',y='Value',hue="Item",data=df7).set_title('Net emissions from World')
# Out:
# Text(0.5, 1.0, 'Net emissions from World')
