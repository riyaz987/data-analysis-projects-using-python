# %% [markdown]
# ## Author: Riyaz Khan

# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %%
df=pd.read_excel('/Users/riyazkhan/Downloads/carbon2020.xlsx')

# %%
df.head()
# Out:
#    Year  fossil emissions excluding carbonation  land-use change emissions  \
# 0  1959                                   2.415                   1.804200
# 1  1960                                   2.548                   1.659441
# 2  1961                                   2.553                   1.593636
# 3  1962                                   2.644                   1.555922
# 4  1963                                   2.794                   1.511243
#
#    atmospheric growth  ocean sink  land sink  cement carbonation sink  \
# 0              2.0448    0.861368   0.677445                 0.012684
# 1              1.5123    0.839096   1.258399                 0.013839
# 2              1.6614    0.716516   0.660306                 0.014726
# 3              1.1928    0.768402   1.408221                 0.015871
# 4              1.2141    0.917365   1.023823                 0.016863
#
#    budget imbalance
# 0          0.622904
# 1          0.583806
# 2          1.093688
# ...

# %%
sns.lineplot(x= 'Year',y='land-use change emissions', data=df).set_title('land-use change emissions')
# Out:
# Text(0.5, 1.0, 'land-use change emissions')

# %%
sns.lineplot(x= 'Year',y='land sink', data=df).set_title('land sink')
# Out:
# Text(0.5, 1.0, 'land sink')

# %%
sns.lineplot(x= 'Year',y='ocean sink', data=df).set_title('ocean sink')
# Out:
# Text(0.5, 1.0, 'ocean sink')

# %%
sns.lineplot(x= 'Year',y='atmospheric growth', data=df).set_title('atmospheric growth rate')
# Out:
# Text(0.5, 1.0, 'atmospheric growth rate')

# %%
sns.lineplot(x= 'Year',y='fossil emissions excluding carbonation', data=df).set_title('fossil emissions excluding carbonation')
# Out:
# Text(0.5, 1.0, 'fossil emissions excluding carbonation')

# %%
sns.lineplot(x= 'Year',y='cement carbonation sink', data=df).set_title('cement carbonation sink')
# Out:
# Text(0.5, 1.0, 'cement carbonation sink')

# %%
sns.lineplot(x= 'Year',y='budget imbalance', data=df).set_title('budget imbalance')
# Out:
# Text(0.5, 1.0, 'budget imbalance')
