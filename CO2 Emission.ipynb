# %% [markdown]
# # Author: Riyaz Khan

# %%
df=pd.read_excel('/Users/riyazkhan/Downloads/owid-co2-data.xlsx')

# %%
import pandas as pd
import numpy as np

# %%
df.head()
# Out:
#   iso_code      country  year    co2  co2_growth_prct  co2_growth_abs  \
# 0      AFG  Afghanistan  1949  0.015              NaN             NaN
# 1      AFG  Afghanistan  1950  0.084          475.000           0.070
# 2      AFG  Afghanistan  1951  0.092            8.696           0.007
# 3      AFG  Afghanistan  1952  0.092              NaN             NaN
# 4      AFG  Afghanistan  1953  0.106           16.000           0.015
#
#    consumption_co2  trade_co2  trade_co2_share  co2_per_capita  ...  \
# 0              NaN        NaN              NaN           0.002  ...
# 1              NaN        NaN              NaN           0.011  ...
# 2              NaN        NaN              NaN           0.012  ...
# 3              NaN        NaN              NaN           0.012  ...
# 4              NaN        NaN              NaN           0.013  ...
#
#    ghg_per_capita  methane  methane_per_capita  nitrous_oxide  \
# 0             NaN      NaN                 NaN            NaN
# ...

# %% [markdown]
# ## Creating boolean mask

# %%
df_asia=df['country']=='Asia'

# %%
df_asia.head()
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4    False
# Name: country, dtype: bool

# %%
asia_ids=df['country'].index[df_asia]

# %%
asia_ids=list(asia_ids)

# %%
len(asia_ids)
# Out:
# 190

# %%
asia_clean = df.loc[asia_ids,:].copy()

# %%
asia_clean
# Out:
#      iso_code country  year        co2  co2_growth_prct  co2_growth_abs  \
# 1008      NaN    Asia  1830      0.003              NaN           0.003
# 1009      NaN    Asia  1831      0.003           20.069           0.001
# 1010      NaN    Asia  1832      0.002          -33.365          -0.001
# 1011      NaN    Asia  1833      0.003           24.988           0.001
# 1012      NaN    Asia  1834        NaN         -100.000          -0.003
# ...       ...     ...   ...        ...              ...             ...
# 1193      NaN    Asia  2015  18870.080            0.753         140.948
# 1194      NaN    Asia  2016  18973.575            0.548         103.495
# 1195      NaN    Asia  2017  19373.878            2.110         400.303
# 1196      NaN    Asia  2018  19917.214            2.804         543.336
# 1197      NaN    Asia  2019  20241.964            1.630         324.750
#
#       consumption_co2  trade_co2  trade_co2_share  co2_per_capita  ...  \
# ...

# %%
import seaborn as sns
sns.lineplot(x='year',y='co2',data=asia_clean).set_title('Asia CO2 Emission')
# Out:
# Text(0.5, 1.0, 'Asia CO2 Emission')

# %%
df_africa=df['country']=='Africa'
africa_ids=df['country'].index[df_africa]
africa_ids=list(africa_ids)
africa_clean = df.loc[africa_ids,:].copy()
sns.lineplot(x='year',y='co2',data=africa_clean).set_title('Africa CO2 Emission')
# Out:
# Text(0.5, 1.0, 'Africa CO2 Emission')

# %%
df_europe=df['country']=='Europe'
europe_ids=df['country'].index[df_europe]
europe_ids=list(europe_ids)
europe_clean = df.loc[europe_ids,:].copy()
sns.lineplot(x='year',y='co2',data=europe_clean).set_title('Europe CO2 Emission')
# Out:
# Text(0.5, 1.0, 'Europe CO2 Emission')

# %%
df_north_america=df['country']=='North America'
north_america_ids=df['country'].index[df_north_america]
north_america_ids=list(north_america_ids)
north_america_clean = df.loc[north_america_ids,:].copy()
sns.lineplot(x='year',y='co2',data=north_america_clean).set_title('North America CO2 Emission')
# Out:
# Text(0.5, 1.0, 'North America CO2 Emission')

# %%
df_south_america=df['country']=='South America'
south_america_ids=df['country'].index[df_south_america]
south_america_ids=list(south_america_ids)
south_america_clean = df.loc[south_america_ids,:].copy()
sns.lineplot(x='year',y='co2',data=south_america_clean).set_title('South America CO2 Emission')
# Out:
# Text(0.5, 1.0, 'South America CO2 Emission')

# %%
df_ocean=df['country']=='Oceania'
ocean_ids=df['country'].index[df_ocean]
ocean_ids=list(ocean_ids)
ocean_clean = df.loc[ocean_ids,:].copy()
sns.lineplot(x='year',y='co2',data=ocean_clean).set_title('Ocean CO2 Emission')
# Out:
# Text(0.5, 1.0, 'Ocean CO2 Emission')

# %% [markdown]
# ## Global CO2 Emission

# %%
df_combine = pd.concat([asia_clean, africa_clean,north_america_clean,south_america_clean,europe_clean])

# %%
df_combine.head(10)
# Out:
#      iso_code country  year    co2  co2_growth_prct  co2_growth_abs  \
# 1008      NaN    Asia  1830  0.003              NaN           0.003
# 1009      NaN    Asia  1831  0.003           20.069           0.001
# 1010      NaN    Asia  1832  0.002          -33.365          -0.001
# 1011      NaN    Asia  1833  0.003           24.988           0.001
# 1012      NaN    Asia  1834    NaN         -100.000          -0.003
# 1013      NaN    Asia  1835    NaN              NaN             NaN
# 1014      NaN    Asia  1836    NaN              NaN             NaN
# 1015      NaN    Asia  1837    NaN              NaN             NaN
# 1016      NaN    Asia  1838    NaN              NaN             NaN
# 1017      NaN    Asia  1839    NaN              NaN             NaN
#
#       consumption_co2  trade_co2  trade_co2_share  co2_per_capita  ...  \
# 1008              NaN        NaN              NaN             0.0  ...
# 1009              NaN        NaN              NaN             0.0  ...
# ...

# %%
df_combine.sort_values(by='year', ascending= True,axis=0)
# Out:
#       iso_code        country  year        co2  co2_growth_prct  \
# 7141       NaN         Europe  1750      9.351              NaN
# 7142       NaN         Europe  1751      9.351              NaN
# 7143       NaN         Europe  1752      9.354            0.039
# 7144       NaN         Europe  1753      9.354              NaN
# 7145       NaN         Europe  1754      9.358            0.039
# ...        ...            ...   ...        ...              ...
# 1197       NaN           Asia  2019  20241.964            1.630
# 15397      NaN  North America  2019   6475.979           -2.386
# 206        NaN         Africa  2019   1434.873            1.603
# 19495      NaN  South America  2019   1085.107           -1.080
# 7410       NaN         Europe  2019   5448.709           -2.736
#
#        co2_growth_abs  consumption_co2  trade_co2  trade_co2_share  \
# 7141              NaN              NaN        NaN              NaN
# ...

# %%
df_combine.dtypes
# Out:
# iso_code                                object
# country                                 object
# year                                     int64
# co2                                    float64
# co2_growth_prct                        float64
# co2_growth_abs                         float64
# consumption_co2                        float64
# trade_co2                              float64
# trade_co2_share                        float64
# co2_per_capita                         float64
# consumption_co2_per_capita             float64
# share_global_co2                       float64
# cumulative_co2                         float64
# share_global_cumulative_co2            float64
# co2_per_gdp                            float64
# consumption_co2_per_gdp                float64
# co2_per_unit_energy                    float64
# cement_co2                             float64
# coal_co2                               float64
# flaring_co2                            float64
# ...

# %%
import matplotlib
df_combine.groupby('year')['co2'].sum().plot()
# Out:
# <AxesSubplot:xlabel='year'>

# %% [markdown]
# Not all countinents have data from 1860 but all continents have data from 1900. So I have removed data from 1900 to plot the time series.

# %%
df3 = df_combine.groupby('year')['co2'].sum()

# %%
world_1900=pd.DataFrame(df3)

# %%
world_1900['year'] = world_1900.index

# %%
world_1900['year'].head()
# Out:
# year
# 1750    1750
# 1751    1751
# 1752    1752
# 1753    1753
# 1754    1754
# Name: year, dtype: int64

# %%
import matplotlib.pyplot as plt

# %%
df_world_1900=world_1900.loc[world_1900['year'] >1899]

# %%
df_world_1900.head()
# Out:
#            co2  year
# year
# 1900  1941.007  1900
# 1901  2004.241  1901
# 1902  2055.510  1902
# 1903  2244.225  1903
# 1904  2267.781  1904

# %%
sns.lineplot(x='year',y='co2',data=df_world_1900).set_title('Global CO2 Emission')
# Out:
# Text(0.5, 1.0, 'Global CO2 Emission')
